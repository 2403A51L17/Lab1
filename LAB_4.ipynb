# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51L17/Lab1/blob/main/LAB_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv ('/content/titanic_clean.csv')

# %%
summary = data.describe()

# %%
print (summary)
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1310.000000  1309.000000  1309.000000  1310.000000  1309.000000
# mean    655.500000     2.294882     0.381971    29.881135     0.498854
# std     378.308736     0.837836     0.486055    12.878277     1.041658
# min       1.000000     1.000000     0.000000     0.166700     0.000000
# 25%     328.250000     2.000000     0.000000    22.000000     0.000000
# 50%     655.500000     3.000000     0.000000    29.881135     0.000000
# 75%     982.750000     3.000000     1.000000    35.000000     1.000000
# max    1310.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch         fare        body  has_cabin_number
# count  1309.000000  1308.000000  121.000000       1310.000000
# mean      0.385027    33.295479  160.809917          0.225191
# std       0.865560    51.758668   97.696922          0.417867
# min       0.000000     0.000000    1.000000          0.000000
# 25%       0.000000     7.895800   72.000000          0.000000
# 50%       0.000000    14.454200  155.000000          0.000000
# 75%       0.000000    31.275000  256.000000          0.000000
# max       9.000000   512.329200  328.000000          1.000000

# %%
print(data.describe(include=['object']))
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1310  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      917   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
import matplotlib.pyplot as plt

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')

# %%
plt.hist(data['age'].dropna(), bins=20, edgecolor='black', color='skyblue')
# Out:
# (array([ 51.,  21.,  22.,  40., 114., 160., 128., 386.,  97.,  64.,  51.,
#          57.,  38.,  27.,  21.,  20.,   5.,   5.,   2.,   1.]),
#  array([ 0.1667  ,  4.158365,  8.15003 , 12.141695, 16.13336 , 20.125025,
#         24.11669 , 28.108355, 32.10002 , 36.091685, 40.08335 , 44.075015,
#         48.06668 , 52.058345, 56.05001 , 60.041675, 64.03334 , 68.025005,
#         72.01667 , 76.008335, 80.      ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # New Section

# %%
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
plt.xlabel('age')
# Out:
# Text(0.5, 0, 'age')

# %%
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.show()

# %%
plt.figure(figsize=(6, 4))

# %%
data['pclass'].value_counts().plot(kind='bar', color='lightcoral')
# Out:
# <Axes: xlabel='pclass'>

# %%
plt.title('Passenger Class Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Class Distribution')

# %%
plt.xlabel('Class')
# Out:
# Text(0.5, 0, 'Class')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.xticks(rotation=0)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
plt.show()

# %%
plt.figure(figsize=(6, 4))

# %%
plt.boxplot(data['age'].dropna(), patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b43b80c6f10>,
#   <matplotlib.lines.Line2D at 0x7b43b80c7850>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b43b80d8150>,
#   <matplotlib.lines.Line2D at 0x7b43b80d8ad0>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7b43b80c6610>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b43b80d9590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b43b80d9ed0>],
#  'means': []}

# %%
boxprops=dict(facecolor='lightgreen')

# %%
plt.title('Box Plot of Age')
# Out:
# Text(0.5, 1.0, 'Box Plot of Age')

# %%
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(data[['age', 'fare', 'sibsp', 'parch']].dropna())

# %%
plt.show()

# %%
correlation_matrix = data[['Age', 'Fare', 'SibSp', 'Parch']].corr()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-1e3ceb0d590b> in <cell line: 0>()
# ----> 1 correlation_matrix = data[['Age', 'Fare', 'SibSp', 'Parch']].corr()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Age', 'Fare', 'SibSp', 'Parch'], dtype='object')] are in the [columns]"

# %%
correlation_matrix = data[['age', 'fare', 'sibsp', 'parch']].corr()

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', cbar=True)
# Out:
# <Axes: >

# %%
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest', 'has_cabin_number'],
#       dtype='object')

# %%
sns.countplot(x='survived', data=data, palette='Set2')
# Out:
# <ipython-input-44-193c9e0592e7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='survived', data=data, palette='Set2')
# <Axes: xlabel='survived', ylabel='count'>

# %%
plt.title('Survival Count')
# Out:
# Text(0.5, 1.0, 'Survival Count')

# %%
plt.xlabel('Survived')
# Out:
# Text(0.5, 0, 'Survived')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.show()

# %%
-sns.violinplot(x='pclass', y='age', data=data, palette='muted')
# Out:
# <ipython-input-51-38e33202ba42>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   -sns.violinplot(x='pclass', y='age', data=data, palette='muted')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-38e33202ba42> in <cell line: 0>()
# ----> 1 -sns.violinplot(x='pclass', y='age', data=data, palette='muted')
#
# TypeError: bad operand type for unary -: 'Axes'

# %%
plt.title('Age Distribution by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Age Distribution by Passenger Class')

# %%
plt.show()

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
